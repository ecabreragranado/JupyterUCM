# %% [markdown]
# ## Interference by multiple beams. Interferential filters.

# %% [markdown]
# The following notebook explains the irradiance obtained in transmission and reflection when a beam hits a thin parallel plane sheet considering the multiple internal reflections that occur in said sheet. It is assumed that the student knows the case of interference by the first two waves reflected or transmitted.

# %% [markdown]
# #### Problem Statement

# %% [markdown]
# Consider a parallel-plane sheet of thickness * h * and refractive index * n *, surrounded by air. The treatment with the first 2 waves reflected or transmitted is a valid approximation when the reflection coefficients are low. Otherwise, it is necessary to consider all the internal reflections produced in the sheet, and consequently, all the transmitted or reflected waves.
#
# Let's see what happens with the irradiance transmitted and reflected in this case. We are interested in seeing what happens when
#
# * change the position of the maximum / minimum obtained in the case of interference with 2 waves.
# * change the contrast.

# %%
from IPython.core.display import Image
Image("http://upload.wikimedia.org/wikipedia/commons/thumb/8/89/Multiple_beam_interference.png/580px-Multiple_beam_interference.png")
